# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshcs2002/LGMVIP-DataScience/blob/main/Task4/LGMVIPtask4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lets Grow More (LGMVIP) - "DATA SCIENCE INTERN"
# # LGMVIP June-23

# %% [markdown]
# ## AUTHOR - HARSH JAISWAL

# %% [markdown]
# ### TASK-4- Image to Pencil Sketch with Python:
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ### For this task i'm using two images, first one is of a peacock image and second one is of a child image

# %% [markdown]
# # Importing openCV2 and other Library

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# # Reading the image

# %%
img1 = cv2.imread('peacock.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=800x532 at 0x7F74E4466EF0>

# %%
img2 = cv2.imread('child.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F74E45C47F0>

# %% [markdown]
# # Creating a new image by converting the original image to greyscale

# %%
gray_image1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image1)
# Out:
# <PIL.Image.Image image mode=L size=800x532 at 0x7F74E44649A0>

# %%
gray_image2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image2)
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7F74E4466AA0>

# %% [markdown]
# # Inverting the new grayscale image

# %%
inverted_image1 = 255 - gray_image1
cv2_imshow(inverted_image1)
# Out:
# <PIL.Image.Image image mode=L size=800x532 at 0x7F750EFEAE60>

# %%
inverted_image2 = 255 - gray_image2
cv2_imshow(inverted_image2)
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7F750EFEB340>

# %% [markdown]
# #  Bluring the image by using the Gaussian Function in OpenCV

# %%
blurred1 = cv2.GaussianBlur(inverted_image1, (21, 21), 0)

# %%
blurred2 = cv2.GaussianBlur(inverted_image2, (21, 21), 0)

# %% [markdown]
# # Inverting the blurred image and then we can easily convert the image into a pencil sketch

# %%
inverted_blurred1 = 255 - blurred1
pencil_sketch1 = cv2.divide(gray_image1, inverted_blurred1, scale=256.0)
cv2_imshow(pencil_sketch1)
# Out:
# <PIL.Image.Image image mode=L size=800x532 at 0x7F750EFEB430>

# %%
inverted_blurred2 = 255 - blurred2
pencil_sketch2 = cv2.divide(gray_image2, inverted_blurred2, scale=256.0)
cv2_imshow(pencil_sketch2)
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7F750EFEB400>

# %% [markdown]
# # looking at both the original image and the pencil sketch

# %%
cv2_imshow(img1)
cv2_imshow(pencil_sketch1)
# Out:
# <PIL.Image.Image image mode=RGB size=800x532 at 0x7F74E44673A0>
# <PIL.Image.Image image mode=L size=800x532 at 0x7F74E44664D0>

# %%
cv2_imshow(img2)
cv2_imshow(pencil_sketch2)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F74E44673A0>
# <PIL.Image.Image image mode=L size=183x275 at 0x7F74E44657B0>

# %% [markdown]
# # Thank You :)
